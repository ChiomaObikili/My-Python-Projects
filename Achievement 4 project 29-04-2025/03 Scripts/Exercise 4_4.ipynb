# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Importing df_ords

# %%
path = r'C:\Users\Apex PC\Achievement 4 project 29-04-2025\03 Scripts\Original Folder\orders.csv'

# %%
path
# Out:
# 'C:\\Users\\Apex PC\\Achievement 4 project 29-04-2025\\03 Scripts\\Original Folder\\orders.csv'

# %%
df_ords = pd.read_csv(os.path.join(path), index_col = False)

# %% [markdown]
# # Importing df_prods

# %%
path = r'C:\Users\Apex PC\Achievement 4 project 29-04-2025\03 Scripts\Original Folder\products.csv'

# %%
path
# Out:
# 'C:\\Users\\Apex PC\\Achievement 4 project 29-04-2025\\03 Scripts\\Original Folder\\products.csv'

# %%
df_prods = pd.read_csv(os.path.join(path), index_col = False)

# %% [markdown]
# # Importing df_dep

# %%
path = r'C:\Users\Apex PC\Achievement 4 project 29-04-2025\03 Scripts\Original Folder\departments.csv'

# %%
path
# Out:
# 'C:\\Users\\Apex PC\\Achievement 4 project 29-04-2025\\03 Scripts\\Original Folder\\departments.csv'

# %%
df_dep = pd.read_csv(os.path.join(path), index_col = False)

# %% [markdown]
# # Wrangling df_ords

# %%
df_ords.drop(columns = ['eval_set'])
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# ...           ...      ...           ...        ...                ...
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
# 3421082    272231   206209            14          6                 14
#
#          days_since_prior_order
# 0                           NaN
# 1                          15.0
# ...

# %%
df_ords = df_ords.drop(columns = ['eval_set'])

# %%
df_ords.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %% [markdown]
# # variable not need in analysis as a numeric variable and change it to a string for df_ords

# %%
df_ords['order_id'] = df_ords['order_id'].astype('str')

# %%
df_ords['user_id'] = df_ords['user_id'].astype('str')

# %%
df_ords['order_id'].dtype
# Out:
# dtype('O')

# %%
df_ords['user_id'].dtype
# Out:
# dtype('O')

# %% [markdown]
# # Renaming "order_dow" column

# %%
df_ords.rename(columns = {'order_dow' : 'orders_day_of_week'}, inplace = True)

# %%
df_ords.head()
# Out:
#   order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329       1             1                   2                  8
# 1  2398795       1             2                   3                  7
# 2   473747       1             3                   3                 12
# 3  2254736       1             4                   4                  7
# 4   431534       1             5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %% [markdown]
# # frequency of the corresponding variable(order_hour_of_day)

# %%
df_ords.describe
# Out:
# <bound method NDFrame.describe of         order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0        2539329       1             1                   2                  8
# 1        2398795       1             2                   3                  7
# 2         473747       1             3                   3                 12
# 3        2254736       1             4                   4                  7
# 4         431534       1             5                   4                 15
# ...          ...     ...           ...                 ...                ...
# 3421078  2266710  206209            10                   5                 18
# 3421079  1854736  206209            11                   4                 10
# 3421080   626363  206209            12                   1                 12
# 3421081  2977660  206209            13                   1                 12
# 3421082   272231  206209            14                   6                 14
#
# ...

# %% [markdown]
# # Get the frequency of orders per hour

# %%
hourly_counts = df_ords['order_hour_of_day'].value_counts(dropna = False)

# %% [markdown]
# # Display the frequency

# %%
print(hourly_counts)
# Out:
# order_hour_of_day
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: count, dtype: int64

# %% [markdown]
# # Find the busiest hour

# %%
busiest_hour = hourly_counts.idxmax()

# %%
busiest_count = hourly_counts.max()

# %%
print(f"The busiest hour for placing orders is {busiest_hour}:00 with {busiest_count} orders.")
# Out:
# The busiest hour for placing orders is 10:00 with 288418 orders.

# %%
df_dep.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %% [markdown]
# # Transposing df_dep

# %%
df_dep.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
df_dep_t = df_dep.T

# %%
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
new_header = df_dep_t.iloc[0]

# %%
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
df_dep_t_new = df_dep_t[1:]

# %%
df_dep_t_new
# Out:
#                   0
# 1            frozen
# 2             other
# 3            bakery
# 4           produce
# 5           alcohol
# 6     international
# 7         beverages
# 8              pets
# 9   dry goods pasta
# 10             bulk
# 11    personal care
# 12     meat seafood
# 13           pantry
# 14        breakfast
# 15     canned goods
# 16       dairy eggs
# 17        household
# 18           babies
# 19           snacks
# 20             deli
# 21          missing

# %%
df_dep_t_new.columns = new_header    #set the header row as the df header

# %%
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %% [markdown]
# # Determine the meaning behind a value of 4 in the "department_id" column within the df_prods dataframe using a data dictionary

# %%
data_dict = df_dep_t_new.to_dict('index')

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
print(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %% [markdown]
# # Subset on breakfast item sales.

# %%
df_breakfast =  df_prods[df_prods['department_id']==14]

# %%
df_prods['department_id']==14
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49688    False
# 49689    False
# 49690    False
# 49691    False
# 49692    False
# Name: department_id, Length: 49693, dtype: bool

# %%
df_breakfast =  df_prods[df_prods['department_id']==14]

# %%
df_breakfast.head()
# Out:
#      product_id                                      product_name  aisle_id  \
# 27           28                                 Wheat Chex Cereal       121
# 33           34                                               NaN       121
# 67           68                           Pancake Mix, Buttermilk       130
# 89           90                                      Smorz Cereal       121
# 210         211  Gluten Free Organic Cereal Coconut Maple Vanilla       130
#
#      department_id  prices
# 27              14    10.1
# 33              14    12.2
# 67              14    13.7
# 89              14     3.9
# 210             14     3.6

# %% [markdown]
# # Subsets for alcohol, deli, beverages, and meat/seafood.

# %%
df_alcohol =  df_prods[df_prods['department_id']==5]      # Subset on alcohol item sales.

# %%
df_alcohol
# Out:
#        product_id                               product_name  aisle_id  \
# 51             52                        Mirabelle Brut Rose       134
# 118           119                     Chardonnay Paso Robles        62
# 149           150                                  Brut Rosé       134
# 233           234                          Tennessee Whiskey       124
# 248           249             Pinot Grigio, California, 2010        62
# ...           ...                                        ...       ...
# 49548       49544                    Cabernet Sauvignon Wine        28
# 49566       49562              Blanc De Noirs Sparkling Wine       134
# 49610       49606                        Organic Natural Red        28
# 49665       49661                                      Porto       134
# 49688       49684  Vodka, Triple Distilled, Twist of Vanilla       124
#
#        department_id  prices
# 51                 5    14.4
# 118                5     5.5
# ...

# %%
df_deli =  df_prods[df_prods['department_id']==20]             # Subset on deli item sales.

# %%
df_deli
# Out:
#        product_id                                   product_name  aisle_id  \
# 48             49  Vegetarian Grain Meat Sausages Italian - 4 CT        14
# 61             62        Premium Deli Oven Roasted Turkey Breast        96
# 73             74                Artisan Chick'n & Apple Sausage        14
# 84             85                           Soppressata Piccante        96
# 108           109                         Grape Leaf Hummus Wrap        13
# ...           ...                                            ...       ...
# 49558       49554                          Roasted Garlic Hommus        67
# 49564       49560    Selects Natural Slow Roasted Chicken Breast        96
# 49585       49581                   Pinto Bean and Cheese Pupusa        13
# 49609       49605                     Classic Hummus Family Size        67
# 49642       49638           Organic Superfirm Vacuum Packed Tofu        14
#
#        department_id  prices
# 48                20    10.1
# ...

# %%
df_beverages =  df_prods[df_prods['department_id']==7]       ## Subset on beverages item sales.

# %%
df_beverages
# Out:
#        product_id                                    product_name  aisle_id  \
# 2               3            Robust Golden Unsweetened Oolong Tea        94
# 6               7                  Pure Coconut Water With Orange        98
# 9              10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10             11                               Peach Mango Juice        31
# 19             20  Pomegranate Cranberry & Aloe Vera Enrich Drink        98
# ...           ...                                             ...       ...
# 49659       49655                                     Apple Cider        98
# 49676       49672                          Cafe Mocha K-Cup Packs        26
# 49679       49675             Cinnamon Dolce Keurig Brewed K Cups        26
# 49680       49676                          Ultra Red Energy Drink        64
# 49686       49682                              California Limeade        98
#
#        department_id  prices
# ...

# %%
df_meat_seafood =  df_prods[df_prods['department_id']==12       # Subset on meat seafood item sales.

# %%
df_meat_seafood
# Out:
#        product_id                                       product_name  \
# 16             17                                  Rendered Duck Fat
# 22             23                             Organic Turkey Burgers
# 34             35     Italian Herb Porcini Mushrooms Chicken Sausage
# 39             40  Beef Hot Links Beef Smoked Sausage With Chile ...
# 83             84                                         Lamb Shank
# ...           ...                                                ...
# 49425       49421                                   Salame, Peppered
# 49440       49436                              Imitation Crab Flakes
# 49509       49505                                Hot Italian Sausage
# 49655       49651                                       Beef Brisket
# 49674       49670                                Beef Summer Sausage
#
#        aisle_id  department_id  prices
# 16           35             12    17.1
# 22           49             12     8.2
# ...

# %% [markdown]
# # informations on "user_id" of “1.”

# %%
df_ords.head()
# Out:
#   order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329       1             1                   2                  8
# 1  2398795       1             2                   3                  7
# 2   473747       1             3                   3                 12
# 3  2254736       1             4                   4                  7
# 4   431534       1             5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_ords['order_id'] = df_ords['order_id'].astype('str')    # changing to strings

# %%
df_ords['user_id'] = df_ords['user_id'].astype('str')     # changing to strings

# %%
df_user_id_1 = df_ords[df_ords['user_id'] == '1']

# %%
df_user_id_1
# Out:
#    order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329       1             1                   2                  8
# 1   2398795       1             2                   3                  7
# 2    473747       1             3                   3                 12
# 3   2254736       1             4                   4                  7
# 4    431534       1             5                   4                 15
# 5   3367565       1             6                   2                  7
# 6    550135       1             7                   1                  9
# 7   3108588       1             8                   1                 14
# 8   2295261       1             9                   1                 16
# 9   2550362       1            10                   4                  8
# 10  1187899       1            11                   4                  8
#
#     days_since_prior_order
# 0                      NaN
# 1                     15.0
# ...

# %% [markdown]
# # Number of orders placed

# %%
print(f"Total orders by user 1: {df_user_id_1.shape[0]}")
# Out:
# Total orders by user 1: 11

# %% [markdown]
# # Time gaps between orders

# %%
print(df_user_id_1['days_since_prior_order'])
# Out:
# 0      NaN
# 1     15.0
# 2     21.0
# 3     29.0
# 4     28.0
# 5     19.0
# 6     20.0
# 7     14.0
# 8      0.0
# 9     30.0
# 10    14.0
# Name: days_since_prior_order, dtype: float64

# %% [markdown]
# # Which days of the week they order

# %%
print(df_user_id_1['orders_day_of_week'].value_counts())
# Out:
# orders_day_of_week
# 4    4
# 1    3
# 2    2
# 3    2
# Name: count, dtype: int64

# %% [markdown]
# # Which hours they usually order

# %%
print(df_user_id_1['order_hour_of_day'].value_counts())
# Out:
# order_hour_of_day
# 8     3
# 7     3
# 12    1
# 15    1
# 9     1
# 14    1
# 16    1
# Name: count, dtype: int64

# %%
df_ords_user_id_1 = df_ords.loc[df_ords['user_id'] == '1']    #using the loc method

# %%
df_ords_user_id_1
# Out:
#    order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329       1             1                   2                  8
# 1   2398795       1             2                   3                  7
# 2    473747       1             3                   3                 12
# 3   2254736       1             4                   4                  7
# 4    431534       1             5                   4                 15
# 5   3367565       1             6                   2                  7
# 6    550135       1             7                   1                  9
# 7   3108588       1             8                   1                 14
# 8   2295261       1             9                   1                 16
# 9   2550362       1            10                   4                  8
# 10  1187899       1            11                   4                  8
#
#     days_since_prior_order
# 0                      NaN
# 1                     15.0
# ...

# %% [markdown]
# # Exporting df_ords dataframe as “orders_wrangled.csv”

# %%
path = r'C:\Users\Apex PC\Achievement 4 project 29-04-2025\03 Scripts\Prepared Folder'

# %%
path
# Out:
# 'C:\\Users\\Apex PC\\Achievement 4 project 29-04-2025\\03 Scripts\\Prepared Folder'

# %%
df_ords.to_csv(os.path.join(path, 'orders_wrangled.csv'))

# %%
df_ords.to_csv(os.path.join(path, 'orders_wrangled.csv'))

# %% [markdown]
# # Exporting df_dep_t_new dataframe as “departments_wrangled.csv”

# %%
df_dep_t_new.to_csv(os.path.join(path, 'departments_wrangled.csv'))
